# %% [markdown]
# ## DATA MINING LAB
# ### DIGITAL ASSIGNMENT-5
# #### HARSH AGRAWAL 22BDS0078

# %% [markdown]
# Description
# In this exercise, you are required to implement the k-means algorithm and write your
# own explanation for the same.

# %%
import numpy as np
from sklearn.cluster import KMeans

# %% [markdown]
# Step 1: Load data from places.txt
# Each line contains a longitude-latitude pair in the format "-112.1,33.5"

# %%
with open("places.txt", "r") as file:
    locations = [list(map(float, line.strip().split(","))) for line in file]

# %% [markdown]
# Step 2:Convert to NumPy array

# %%
locations = np.array(locations)

# %% [markdown]
# Step 3:Apply K-Means clustering with k=3

# %%
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
labels = kmeans.fit_predict(locations)

# %% [markdown]
# Step 4:Write output to clusters.txt

# %%
with open("clusters.txt", "w") as file:
    for idx, label in enumerate(labels):
        file.write(f"{idx} {label}\n")

# %% [markdown]
# Step 5:Print completion message

# %%
print("Clustering complete. Output saved in clusters.txt")
# Out:
# Clustering complete. Output saved in clusters.txt

# %% [markdown]
# Step 7: Print the output file

# %%
with open("clusters.txt", "r") as file:
    for line in file:
        print(line.strip())
# Out:
# 0 0
# 1 0
# 2 0
# 3 0
# 4 1
# 5 1
# 6 2
# 7 0
# 8 0
# 9 2
# 10 0
# 11 2
# 12 1
# 13 0
# 14 2
# 15 2
# 16 2
# 17 0
# 18 2
# 19 1
# 20 1
# 21 1
# 22 1
# 23 2
# 24 0
# 25 1
# 26 0
# 27 1
# 28 0
# 29 0
# 30 1
# 31 2
# 32 0
# 33 0
# 34 0
# 35 2
# 36 1
# 37 0
# 38 1
# 39 2
# 40 2
# 41 2
# 42 2
# 43 2
# 44 2
# 45 1
# 46 0
# 47 2
# 48 0
# 49 0
# 50 1
# 51 2
# 52 0
# 53 2
# 54 1
# 55 2
# 56 0
# 57 2
# 58 1
# 59 2
# 60 0
# 61 1
# 62 2
# 63 0
# 64 1
# 65 2
# 66 2
# 67 0
# 68 1
# 69 2
# 70 1
# 71 0
# 72 2
# 73 1
# 74 0
# 75 0
# 76 0
# 77 2
# 78 1
# 79 0
# 80 0
# 81 2
# 82 0
# 83 1
# 84 0
# 85 0
# 86 1
# 87 0
# 88 1
# 89 0
# 90 1
# 91 1
# 92 0
# 93 1
# 94 1
# 95 1
# 96 2
# 97 2
# 98 0
# 99 0
# 100 0
# 101 1
# 102 0
# 103 0
# 104 2
# 105 2
# 106 0
# 107 1
# 108 0
# 109 0
# 110 1
# 111 2
# 112 0
# 113 1
# 114 0
# 115 0
# 116 1
# 117 0
# 118 1
# 119 1
# 120 2
# 121 2
# 122 0
# 123 1
# 124 2
# 125 1
# 126 2
# 127 1
# 128 2
# 129 1
# 130 2
# 131 1
# 132 2
# 133 0
# 134 0
# 135 1
# 136 1
# 137 0
# ...
